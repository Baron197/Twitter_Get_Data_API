# %%
import pandas as pd
import json

# %%
tweetList = []

# %%
with open('google.json') as json_file:  
    data = json.load(json_file)
   
    for item in data :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        theTweet = item['text']
        if('extended_tweet' in item.keys()) :
            theTweet = item['extended_tweet']['full_text']
        tweetList.append([item['id'], 
                          item['created_at'], 
                          theTweet,
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags,
                          item['source']])
        
dfStream = pd.DataFrame(tweetList, columns=['id','createdDate',
                                            'text','userId',
                                            'userName','userAccount',
                                            'hashtags','source'])
dfStream
# Out:
#                     id                     createdDate  \
# 0  1115519344405098496  Tue Apr 09 07:38:31 +0000 2019
# 1  1115519346338598912  Tue Apr 09 07:38:32 +0000 2019
# 2  1115519348959920128  Tue Apr 09 07:38:32 +0000 2019
# 3  1115519352718204933  Tue Apr 09 07:38:33 +0000 2019
# 4  1115519354399903744  Tue Apr 09 07:38:34 +0000 2019
# 5  1115519354752458752  Tue Apr 09 07:38:34 +0000 2019
# 6  1115519360255184896  Tue Apr 09 07:38:35 +0000 2019
# 7  1115519361421279233  Tue Apr 09 07:38:35 +0000 2019
# 8  1115519363602370560  Tue Apr 09 07:38:36 +0000 2019
# 9  1115519363795357697  Tue Apr 09 07:38:36 +0000 2019
#
#                                                 text               userId  \
# 0  RT @AMI895_AMI: All are equal. #WomeninTech #w...            943917032
# 1  RT @candouragency: 🎙️ Episode 4 of Search with...            409658166
# 2  RT @RenwaX23: Xiaomi Mi Browser + Mint Browser...            147175291
# ...

# %%
dfStream.loc[7,'text']
# Out:
# 'google at xxxl porno klips comics sex gallery girlfriend porn uk nude raider game lisa matthews naked  https://t.co/9njaDaknbd'

# %%
tweetList = []
with open('scoopy.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        theTweet = item['text']
        if('extended_tweet' in item.keys()) :
            theTweet = item['extended_tweet']['full_text']
        tweetList.append([item['id'], 
                          item['created_at'], 
                          theTweet,
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfSearchScoopy = pd.DataFrame(tweetList, columns=['id','createdDate','text',
                                                 'userId','userName','userAccount',
                                                 'hashtags'])
dfSearchScoopy
# Out:
#                     id                     createdDate  \
# 0  1114881615258218497  Sun Apr 07 13:24:25 +0000 2019
# 1  1114502188951166976  Sat Apr 06 12:16:42 +0000 2019
# 2  1114444233589395456  Sat Apr 06 08:26:25 +0000 2019
# 3  1114441204672880640  Sat Apr 06 08:14:23 +0000 2019
# 4  1114440301542686720  Sat Apr 06 08:10:47 +0000 2019
# 5  1113823522726375425  Thu Apr 04 15:19:56 +0000 2019
# 6  1113087281466826752  Tue Apr 02 14:34:22 +0000 2019
# 7  1113016462627622912  Tue Apr 02 09:52:58 +0000 2019
# 8  1112723671884267522  Mon Apr 01 14:29:31 +0000 2019
#
#                                                 text               userId  \
# 0  @bramsaputraa walaaaah skrng motornya udah bis...           2799713704
# 1  @koernaen ini badan bukan scoopy yang di unbox...            435587738
# 2  RT @gukgukguk_: ✨ Cie viral\n\nJanuari : 80jt\...           1165789080
# 3  RT @gukgukguk_: ✨ Cie viral\n\nJanuari : 80jt\...  1005807329655156736
# ...

# %%
dfSearchScoopy.loc[8, 'userName']
# Out:
# 'fan🐧'

# %%
tweetList = []
with open('search1.json') as json_file:  
    data = json.load(json_file)
    item = data['statuses'][0]
    hashtags = ''
    for hashtag in item['entities']['hashtags']:
        hashtags += hashtag['text'] + ' ';
    tweetList.append([item['id'], 
                      item['created_at'], 
                      item['text'],
                      item['user']['id'],
                      item['user']['name'],
                      item['user']['screen_name'],
                      hashtags])
dfSearch = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfSearch
# Out:
#                     id                     createdDate  \
# 0  1052218752454995968  Tue Oct 16 15:24:34 +0000 2018
#
#                                                 text     userId  \
# 0  Testing for Data Science Class Purwadhika\n\n#...  335913267
#
#           userName   userAccount                   hashtags
# 0  Baron P.Hartono  BaronHartono  databertasbih kucinggans

# %%
tweetList = []
with open('cammodel.json') as json_file:  
    data = json.load(json_file)
   
    for item in data :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        theTweet = item['text']
        if('extended_tweet' in item.keys()) :
            theTweet = item['extended_tweet']['full_text']
        tweetList.append([item['id'], 
                          item['created_at'], 
                          theTweet,
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
        
dfUserTweets = pd.DataFrame(tweetList, columns=['id','createdDate','text',
                                                'userId','userName','userAccount',
                                                'hashtags'])
dfUserTweets
# Out:
#                      id                     createdDate  \
# 0   1115536028637511681  Tue Apr 09 08:44:49 +0000 2019
# 1   1115535956206075904  Tue Apr 09 08:44:32 +0000 2019
# 2   1115535796700876800  Tue Apr 09 08:43:54 +0000 2019
# 3   1115535707186126848  Tue Apr 09 08:43:32 +0000 2019
# 4   1115535574360834050  Tue Apr 09 08:43:01 +0000 2019
# 5   1115535470476374017  Tue Apr 09 08:42:36 +0000 2019
# 6   1115535343875502080  Tue Apr 09 08:42:06 +0000 2019
# 7   1115535127638085632  Tue Apr 09 08:41:14 +0000 2019
# 8   1115535043949211650  Tue Apr 09 08:40:54 +0000 2019
# 9   1115534806241173504  Tue Apr 09 08:39:58 +0000 2019
# 10  1115534666281439233  Tue Apr 09 08:39:24 +0000 2019
# 11  1115534501353013248  Tue Apr 09 08:38:45 +0000 2019
# 12  1115534395039977473  Tue Apr 09 08:38:20 +0000 2019
# 13  1115534165867421696  Tue Apr 09 08:37:25 +0000 2019
# 14  1115534047080591360  Tue Apr 09 08:36:57 +0000 2019
# 15  1115533958056501248  Tue Apr 09 08:36:35 +0000 2019
# ...

# %%
tweetList = []
with open('stream1.json') as json_file:  
    data = json.load(json_file)
   
    for item in data :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
        
dfStream1 = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfStream1
# Out:
#                     id                     createdDate  \
# 0  1052449854809624578  Wed Oct 17 06:42:53 +0000 2018
# 1  1052449858416726017  Wed Oct 17 06:42:54 +0000 2018
# 2  1052449860975284227  Wed Oct 17 06:42:55 +0000 2018
# 3  1052449862271291394  Wed Oct 17 06:42:55 +0000 2018
# 4  1052449862741106688  Wed Oct 17 06:42:55 +0000 2018
# 5  1052449864733388801  Wed Oct 17 06:42:55 +0000 2018
# 6  1052449864943054853  Wed Oct 17 06:42:56 +0000 2018
# 7  1052449865823911938  Wed Oct 17 06:42:56 +0000 2018
# 8  1052449874199932928  Wed Oct 17 06:42:58 +0000 2018
# 9  1052449876737445888  Wed Oct 17 06:42:58 +0000 2018
#
#                                                 text              userId  \
# 0  Google will charge Android manufacturers for t...            26001977
# 1  King of dark fantasy. Summon today. App Store:...            14535292
# 2  RT @richardcalhoun: #Grieve represents the @Be...            14368178
# ...

# %%
tweetList = []
with open('yoga.json') as json_file:  
    data = json.load(json_file)
   
    for item in data :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
        
dfStream1 = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfStream1
# Out:
#                     id                     createdDate  \
# 0  1052450732069318656  Wed Oct 17 06:46:22 +0000 2018
# 1  1052450773219590145  Wed Oct 17 06:46:32 +0000 2018
# 2  1052450781071376385  Wed Oct 17 06:46:34 +0000 2018
# 3  1052450789770387460  Wed Oct 17 06:46:36 +0000 2018
# 4  1052450808665661440  Wed Oct 17 06:46:41 +0000 2018
# 5  1052450829947625474  Wed Oct 17 06:46:46 +0000 2018
# 6  1052450843830743040  Wed Oct 17 06:46:49 +0000 2018
# 7  1052450849224560640  Wed Oct 17 06:46:50 +0000 2018
# 8  1052450876047220736  Wed Oct 17 06:46:57 +0000 2018
# 9  1052450899279454210  Wed Oct 17 06:47:02 +0000 2018
#
#                                                 text               userId  \
# 0  Scuffles Break Out at Indian Temple Town Over ...             41552379
# 1  Trail run with the pooch and yoga. \n*breeeeea...            293440597
# 2              @TradesTalk A bit of yoga #TradesTalk   767738190572683266
# ...

# %%
tweetList = []
with open('teletubies.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfSearchYoung = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfSearchYoung
# Out:
#                      id                     createdDate  \
# 0   1052483236096487424  Wed Oct 17 08:55:32 +0000 2018
# 1   1052481755238682624  Wed Oct 17 08:49:39 +0000 2018
# 2   1052481679313358848  Wed Oct 17 08:49:21 +0000 2018
# 3   1052481558890799104  Wed Oct 17 08:48:52 +0000 2018
# 4   1052481518239502336  Wed Oct 17 08:48:42 +0000 2018
# 5   1052481458160320512  Wed Oct 17 08:48:28 +0000 2018
# 6   1052481200302960640  Wed Oct 17 08:47:26 +0000 2018
# 7   1052481125061255168  Wed Oct 17 08:47:09 +0000 2018
# 8   1052481038679592960  Wed Oct 17 08:46:48 +0000 2018
# 9   1052480977786695680  Wed Oct 17 08:46:33 +0000 2018
# 10  1052480885751042048  Wed Oct 17 08:46:11 +0000 2018
# 11  1052480784852869120  Wed Oct 17 08:45:47 +0000 2018
# 12  1052460332281675776  Wed Oct 17 07:24:31 +0000 2018
# 13  1052356240225890304  Wed Oct 17 00:30:54 +0000 2018
# 14  1052250223609753605  Tue Oct 16 17:29:37 +0000 2018
# 15  1052245582008311808  Tue Oct 16 17:11:11 +0000 2018
# ...

# %%
tweetList = []
with open('nlp.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfSearchYoung = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfSearchYoung
# Out:
#                     id                     createdDate  \
# 0  1052484292851318784  Wed Oct 17 08:59:44 +0000 2018
# 1  1052484221124587520  Wed Oct 17 08:59:27 +0000 2018
# 2  1052484173930196992  Wed Oct 17 08:59:15 +0000 2018
# 3  1052484153973780486  Wed Oct 17 08:59:11 +0000 2018
# 4  1052484032905207808  Wed Oct 17 08:58:42 +0000 2018
# 5  1052484010352377856  Wed Oct 17 08:58:36 +0000 2018
# 6  1052483708417015810  Wed Oct 17 08:57:24 +0000 2018
# 7  1052483040721739776  Wed Oct 17 08:54:45 +0000 2018
# 8  1052482979769905154  Wed Oct 17 08:54:31 +0000 2018
# 9  1052482510511255552  Wed Oct 17 08:52:39 +0000 2018
#
#                                                 text               userId  \
# 0  RT @ParallelDots: India among top 15 in artifi...           2409188870
# 1  RT @BristowColin: Big Data: Planning for Peak ...   934160485993340933
# 2  RT @BristowColin: Big Data Shaping the Future ...   953289572464635904
# ...

# %%
dfSearchYoung.iloc[2]['text']
# Out:
# 'RT @BristowColin: Big Data Shaping the Future of Ag Industry on the HAT Wednesday Morning Edition\nRead more here: https://t.co/i1O00N8LkU…'

# %%
tweetList = []
with open('yoga1.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfSearchYoung = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfSearchYoung
# Out:
#                     id                     createdDate  \
# 0  1093792163102683137  Fri Feb 08 08:42:28 +0000 2019
# 1  1093792158446960640  Fri Feb 08 08:42:26 +0000 2019
# 2  1093792117539946497  Fri Feb 08 08:42:17 +0000 2019
# 3  1093792079396900864  Fri Feb 08 08:42:08 +0000 2019
# 4  1093792026414309376  Fri Feb 08 08:41:55 +0000 2019
# 5  1093792022438309888  Fri Feb 08 08:41:54 +0000 2019
# 6  1093792017627389952  Fri Feb 08 08:41:53 +0000 2019
# 7  1093792003803041792  Fri Feb 08 08:41:50 +0000 2019
# 8  1093791985402556417  Fri Feb 08 08:41:45 +0000 2019
#
#                                                 text               userId  \
# 0  We have to stop and be humble enough to unders...            488559778
# 1  RT @BJP4Rajasthan: #ForTheFirstTime India’s so...  1056816205120593920
# 2  23″ Yoga half Ball Balance Trainer Fitness Pil...   904953941514784768
# 3  RT @KathyChr: I wish university mental health ...             15330022
# ...

# %%
tweetList = []
with open('purwadhika1.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfPurwadhika = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfPurwadhika
# Out:
#                     id                     createdDate  \
# 0  1093552618733858816  Thu Feb 07 16:50:36 +0000 2019
# 1  1093192372316323840  Wed Feb 06 16:59:06 +0000 2019
# 2  1093192319262543872  Wed Feb 06 16:58:54 +0000 2019
# 3  1093133921275981824  Wed Feb 06 13:06:50 +0000 2019
# 4  1093133888442880002  Wed Feb 06 13:06:43 +0000 2019
# 5  1093133859716124674  Wed Feb 06 13:06:36 +0000 2019
# 6  1093132989599379456  Wed Feb 06 13:03:08 +0000 2019
# 7  1093132985858023424  Wed Feb 06 13:03:07 +0000 2019
# 8  1093132972960624645  Wed Feb 06 13:03:04 +0000 2019
# 9  1093132912638054400  Wed Feb 06 13:02:50 +0000 2019
#
#                                                 text              userId  \
# 0  Dear @kempanrb dan @BKNgoid apakah PNS/ASN yg ...           237283752
# 1  RT @JeniusConnect: Sekarang kamu bisa belajar ...           427510607
# 2  RT @JeniusConnect: Yang ditunggu-tunggu akhirn...           427510607
# ...

# %%
for tweet in dfPurwadhika['text'] :
    print(tweet)
    print('\n')
# Out:
# Dear @kempanrb dan @BKNgoid apakah PNS/ASN yg share posting seperti ini di akun FBnya tdk menyalahi aturan netralitas?
#
#
# RT @JeniusConnect: Sekarang kamu bisa belajar membuat aplikasi dengan kerangka React Native, coding dan UI design dengan Jenius Tech Team.…
#
#
# RT @JeniusConnect: Yang ditunggu-tunggu akhirnya tiba nih. Kali ini Jenius X @Purwadhika_ID berkolaborasi untuk membuat rangkaian acara tal…
#
#
# RT @JeniusConnect: Yang ditunggu-tunggu akhirnya tiba nih. Kali ini Jenius X @Purwadhika_ID berkolaborasi untuk membuat rangkaian acara tal…
#
#
# RT @JeniusConnect: Sekarang kamu bisa belajar membuat aplikasi dengan kerangka React Native, coding dan UI design dengan Jenius Tech Team.…
#
#
# RT @JeniusConnect: Buat yang tertarik dengan workshop kreatif Jenius X @Purwadhika_ID Nantikan informasi terbarunya ya!
#
#
# Buat yang tertarik dengan workshop kreatif Jenius X @Purwadhika_ID Nantikan informasi terbarunya ya!
#
#
# ...

# %%
tweetList = []
with open('scoopy1.json') as json_file:  
    data = json.load(json_file)
    listTweets = data['statuses']
    for item in listTweets :
        hashtags = ''
        for hashtag in item['entities']['hashtags']:
            hashtags += hashtag['text'] + ' ';
        tweetList.append([item['id'], 
                          item['created_at'], 
                          item['text'],
                          item['user']['id'],
                          item['user']['name'],
                          item['user']['screen_name'],
                          hashtags])
dfPurwadhika = pd.DataFrame(tweetList, columns=['id','createdDate','text','userId','userName','userAccount','hashtags'])
dfPurwadhika
# Out:
#                     id                     createdDate  \
# 0  1093793356801437696  Fri Feb 08 08:47:12 +0000 2019
# 1  1093793307627384838  Fri Feb 08 08:47:00 +0000 2019
#
#                                                 text               userId  \
# 0  Adi Saputra, cowo yg kemaren unboxing Honda Sc...  1048836117506666496
# 1  RT @satriaoo: Teruntuk mbak-mbak yang ada di v...            761418920
#
#      userName   userAccount hashtags
# 0  yantiyanti  Yusmayanti11
# 1   akun lama       suwumpa

# %%
for tweet in dfPurwadhika['text'] :
    print(tweet)
    print('\n')
# Out:
# Adi Saputra, cowo yg kemaren unboxing Honda Scoopy, nangis di depan pak polisi....
#
# Drama banget hidup mu Di....… https://t.co/mKBe4vKAxU
#
#
# RT @satriaoo: Teruntuk mbak-mbak yang ada di video unboxing scoopy, sabar ya.........
#
# Cara Tuhan nunjukkin sifat pasangan itu emang beda-b…
